# %%
import pandas as pd 
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df_covid = pd.read_csv('country_wise_latest.csv')

# %%
df_covid.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df_covid.describe(include='all')
# Out:
#        Country/Region     Confirmed         Deaths     Recovered  \
# count             187  1.870000e+02     187.000000  1.870000e+02
# unique            187           NaN            NaN           NaN
# top           Estonia           NaN            NaN           NaN
# freq                1           NaN            NaN           NaN
# mean              NaN  8.813094e+04    3497.518717  5.063148e+04
# std               NaN  3.833187e+05   14100.002482  1.901882e+05
# min               NaN  1.000000e+01       0.000000  0.000000e+00
# 25%               NaN  1.114000e+03      18.500000  6.265000e+02
# 50%               NaN  5.059000e+03     108.000000  2.815000e+03
# 75%               NaN  4.046050e+04     734.000000  2.260600e+04
# max               NaN  4.290259e+06  148011.000000  1.846641e+06
#
#               Active     New cases   New deaths  New recovered  \
# count   1.870000e+02    187.000000   187.000000     187.000000
# ...

# %%
df_covid.isna().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
df_covid['WHO Region'].value_counts()
# Out:
# Europe                   56
# Africa                   48
# Americas                 35
# Eastern Mediterranean    22
# Western Pacific          16
# South-East Asia          10
# Name: WHO Region, dtype: int64

# %%
df_covid['WHO Region'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What are the five most countries expected to have reached the method of making a vaccine?What countries have succeeded in confronting the Corona virus?

# %% [markdown]
# #### This question expects to see that which are top weakest countries struggles with covid 19? This is why we need to check :
# #### numbers of Recovered / 100 Cases
# #### numbers of Deaths / 100 Cases
# #### Confirmed cases

# %%
df_covid.sort_values(ascending = False, by = ['Confirmed','Deaths / 100 Cases']).head().sort_values(ascending = True, by = ['Deaths / 100 Recovered'])
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 138         Russia     816680   13334     602249   201097       5607
# 154   South Africa     452529    7067     274925   170537       7096
# 79           India    1480073   33408     951166   495499      44457
# 23          Brazil    2442375   87618    1846641   508116      23284
# 173             US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 138          85           3077                1.63                  73.74
# 154         298           9848                1.56                  60.75
# 79          637          33598                2.26                  64.26
# 23          614          33728                3.59                  75.61
# 173        1076          27941                3.45                  30.90
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %% [markdown]
# #### one of the best country for healthcare is Russia. Expected results that analysis shows us Russia for the 1th.

# %%
df_covid.sort_values(ascending =  False, by = ['Deaths / 100 Cases', 'Confirmed']).head().sort_values(ascending = True, by = ['Recovered / 100 Cases']).head(1)
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 177  United Kingdom     301708   45844       1437  254427        688
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 177           7              3               15.19                   0.48
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 177                 3190.26               296944           4764
#
#      1 week % increase WHO Region
# 177                1.6     Europe

# %% [markdown]
# #### it seems that UK should be complately closed during the pandemic.

# %%
df_covid.sort_values(ascending = False, by =['Recovered / 100 Cases']).head().sort_values(ascending = True, by =['Deaths','Confirmed']).head(1)
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 75       Holy See         12       0         12       0          0
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 75           0              0                 0.0                  100.0
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 75                     0.0                   12              0
#
#     1 week % increase WHO Region
# 75                0.0     Europe

# %% [markdown]
# #### Holy See is the country least affected by the Corona virus and that's becaise dominica is an island in the middle of the sea

# %%
df_covid.sort_values(ascending = False, by = ['Active']).head(3)
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
# 23          Brazil    2442375   87618    1846641   508116      23284
# 79           India    1480073   33408     951166   495499      44457
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# 23          614          33728                3.59                  75.61
# 79          637          33598                2.26                  64.26
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
# 23                     4.74              2118646         323729
# 79                     3.51              1155338         324735
#
#      1 week % increase       WHO Region
# 173              11.88         Americas
# 23               15.28         Americas
# ...

# %% [markdown]
# #### as we see Active cases nowadays, these 3 countries need healt cares assitance.

# %%
sb.displot(df_covid['Deaths / 100 Cases'])

# %%
sb.relplot(x='Deaths / 100 Cases',y='Recovered / 100 Cases',hue='WHO Region', data=df_covid)
